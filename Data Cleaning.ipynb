# %%
## Data Cleaning

Let's Clean the data make it more readable format
# lets format the amount of currency

import locale # to format currency

locale.setlocale(locale.LC_ALL, "en_IN")

# create Function to map the Currency to Indian Rupees

def format_inr(amount):
    rounded_amount = round(amount,2)
    return locale.currency(rounded_amount, grouping=True)

# formating numeric values
def format_num(value):
    return f"{value:,}"
state_dict = {
    'andaman-&-nicobar-islands': 'Andaman & Nicobar Islands',
    'andhra-pradesh': 'Andhra Pradesh',
    'arunachal-pradesh': 'Arunachal Pradesh',
    'assam': 'Assam',
    'bihar': 'Bihar',
    'chandigarh': 'Chandigarh',
    'chhattisgarh': 'Chhattisgarh',
    'dadra-&-nagar-haveli-&-daman-&-diu': 'Dadra & Nagar Haveli & Daman & Diu',
    'delhi': 'Delhi',
    'goa': 'Goa',
    'gujarat': 'Gujarat',
    'haryana': 'Haryana',
    'himachal-pradesh': 'Himachal Pradesh',
    'jammu-&-kashmir': 'Jammu & Kashmir',
    'jharkhand': 'Jharkhand',
    'karnataka': 'Karnataka',
    'kerala': 'Kerala',
    'ladakh': 'Ladakh',
    'lakshadweep': 'Lakshadweep',
    'madhya-pradesh': 'Madhya Pradesh',
    'maharashtra': 'Maharashtra',
    'manipur': 'Manipur',
    'meghalaya': 'Meghalaya',
    'mizoram': 'Mizoram',
    'nagaland': 'Nagaland',
    'odisha': 'Odisha',
    'puducherry': 'Puducherry',
    'punjab': 'Punjab',
    'rajasthan': 'Rajasthan',
    'sikkim': 'Sikkim',
    'tamil-nadu': 'Tamil Nadu',
    'telangana': 'Telangana',
    'tripura': 'Tripura',
    'uttar-pradesh': 'Uttar Pradesh',
    'uttarakhand': 'Uttarakhand',
    'west-bengal': 'West Bengal'
}

print(state_dict)

# Aggregated Data

data = pd.read_csv("Data/aggregated/agg_insurance.csv")
data.head()

data["Amount"] = data["Amount"].map(format_inr)
data["Average Transaction"] = data["Average Transaction"].map(format_inr)
data["Count"] = data["Count"].map(format_num)
data.to_csv("Data/aggregated/agg_insurance.csv", index=False)


data.head()
# Cleaning Aggregated State Insurance

data = pd.read_csv("Data/aggregated/state_agg_insurance.csv")
data.head()
# Data Transformation
data["State"] = data["State"].replace(state_dict)
data["Amount"] = data["Amount"].map(format_inr)
data["Average Transaction"] = data["Average Transaction"].map(format_inr)
data["Count"] = data["Count"].map(format_num)

data.to_csv("Data/aggregated/state_agg_insurance.csv", index=False)
data.head()
# Aggregated Transaction
data = pd.read_csv("Data/aggregated/agg_transaction.csv")
data.head()
# Data Transformation
data["Amount"] = data["Amount"].map(format_inr)
data["Average Transaction"] = data["Average Transaction"].map(format_inr)
data["Count"] = data["Count"].map(format_num)
data.to_csv("Data/aggregated/agg_transaction.csv", index=False)
data.head()
# Transaction by States
data = pd.read_csv("Data/aggregated/state_agg_transaction.csv")
data.head()
# Data Transformation
data["State"] = data["State"].replace(state_dict)
data["Count"] = data["Count"].map(format_num)
data["Amount"] = data["Amount"].map(format_inr)
data["Average Transaction"] = data["Average Transaction"].map(format_inr)

data.to_csv("Data/aggregated/state_agg_transaction.csv", index=False)
data.head()
# Aggregated Users Data Frame
data = pd.read_csv("Data/aggregated/agg_Users.csv")
data.head()
# Data Transformation
data["Count"] = data["Count"].map(format_num)
data.to_csv("Data/aggregated/agg_Users.csv", index=False)
data.head()
# Aggregated States Users Data Frame

data =  pd.read_csv("Data/aggregated/state_agg_Users.csv")
data.head()
# Data Transformation
data["State"] = data["State"].replace(state_dict)
data["Count"] = data["Count"].map(format_num)

data.to_csv("Data/aggregated/state_agg_Users.csv", index=False)
data.head()
# Insurnace Map

data =  pd.read_csv("Data/map/map_insurance.csv")
data.head()
# Create a Csv files for data frame
data["Amount"] = data["Amount"].map(format_inr)
data["State"] = data["State"].replace(state_dict)
data.to_csv("Data/map/map_insurance.csv", index=False)
data.head()
# State Map Insurance
data = pd.read_csv("Data/map/state_map_insurance.csv")
data.head()
# Data Tranformation
data["State"] = data["State"].replace(state_dict)
data["District"] = data["District"].str.title()
data["Amount"] = data["Amount"].map(format_inr)

data.to_csv("Data/map/state_map_insurance.csv", index=False)
data.head()
# Hover Insurance
data = pd.read_csv("Data/map/hover/insurance_hover.csv")
data.head()
# Data Tranformation
data["State"] = data["State"].replace(state_dict)
data["Amount"] = data["Amount"].map(format_inr)
data["Average Transaction"] = data["Average Transaction"].map(format_inr)

data.to_csv("Data/map/hover/insurance_hover.csv", index=False)
data.head()
# Hover insurance by states
data = pd.read_csv("Data/map/hover/insurance_state_hover.csv")
data.head()
# Data Tranformation
data["State"] = data["State"].replace(state_dict)
data["District"] = data["District"].str.title()
data["Amount"] = data["Amount"].map(format_inr)
data["Average Transaction"] = data["Average Transaction"].map(format_inr)
data["Count"] = data["Count"].map(format_num)

data.to_csv("Data/map/hover/insurance_state_hover.csv", index=False)
data.head()
# Hover Transaction
data = pd.read_csv("Data/map/hover/transaction_hover.csv")
data.head()
# Data Tranformation
data["State"] = data["State"].replace(state_dict)
data["Count"] = data["Count"].map(format_num)
data["Amount"] = data["Amount"].map(format_inr)
data["Average Transaction"] = data["Average Transaction"].map(format_inr)


data.to_csv("Data/map/hover/transaction_hover.csv", index=False)
data.head()
# Hover Transaction by states

data = pd.read_csv("Data/map/hover/transaction_state_hover.csv")
data.head()
# Data Tranformation
data["State"] = data["State"].replace(state_dict)
data["Count"] = data["Count"].map(format_num)
data["Amount"] = data["Amount"].map(format_inr)
data["District"] = data["District"].str.title()
data["Average Transaction"] = data["Average Transaction"].map(format_inr)

data.to_csv("Data/map/hover/transaction_state_hover.csv", index=False)
data.head()
# Hover user

data = pd.read_csv("Data/map/hover/Users_hover.csv")
data.head()
data["State"].unique()
data["State"] = data["State"].str.title()
data["App Opens"] = data["App Opens"].map(format_num)
data["Registered Users"] = data["Registered Users"].map(format_num)
data["Average Opens"] = data["Average Opens"].map(format_num)

data.to_csv("Data/map/hover/Users_hover.csv", index=False)
data.head()
# Hover user by state

data = pd.read_csv("Data/map/hover/Users_states_hover.csv")
data.head()
# Data Tranformation
data["State"] = data["State"].replace(state_dict)
data["App Opens"] = data["App Opens"].map(format_num)
data["Registered Users"] = data["Registered Users"].map(format_num)
data["Average Opens"] = data["Average Opens"].map(format_num)
data["District"] = data["District"].str.title()

data.to_csv("Data/map/hover/Users_states_hover.csv", index=False)
data.head()
